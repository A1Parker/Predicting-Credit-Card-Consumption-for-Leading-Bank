# %% [markdown]
# # Credit Card Consumption Prediction
# ## Business Problem
# Understanding consumer credit card spending is crucial for banks to develop personalized marketing campaigns and manage credit risk. This project aims to predict customers' credit card consumption for the next three months based on past spending behavior and demographic information.
#
# ## Objectives
# - Perform **Exploratory Data Analysis (EDA)** to identify trends and missing values.
# - **Impute missing values** using appropriate statistical techniques.
# - Build a **predictive model** to forecast credit card consumption.
# - Evaluate model performance using **Root Mean Square Percentage Error (RMSPE)**.

# %%
## Importing neccessary library
import pandas as pd
import numpy as np
import scipy.stats as stats
import itertools

# %%
import statsmodels.formula.api as smf
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# %%
# Importing all 3 data sets
cust_con = pd.read_excel(r"C:\MACHINE LEARNING\PROJECT\11. Capstone Case Study - Predict Cred Card Consumption (1)\CreditConsumptionData.xlsx")
cust_behav = pd.read_excel(r"C:\MACHINE LEARNING\PROJECT\11. Capstone Case Study - Predict Cred Card Consumption (1)\CustomerBehaviorData.xlsx")
cust_demo = pd.read_excel(r"C:\MACHINE LEARNING\PROJECT\11. Capstone Case Study - Predict Cred Card Consumption (1)\CustomerDemographics.xlsx")

# %%
cust_demo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 10 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ID                            20000 non-null  int64
#  1   account_type                  19999 non-null  object
#  2   gender                        19999 non-null  object
#  3   age                           20000 non-null  int64
#  4   Income                        19999 non-null  object
#  5   Emp_Tenure_Years              20000 non-null  float64
#  6   Tenure_with_Bank              20000 non-null  int64
#  7   region_code                   19999 non-null  float64
#  8   NetBanking_Flag               20000 non-null  int64
#  9   Avg_days_between_transaction  19997 non-null  float64
# dtypes: float64(3), int64(4), object(3)
# memory usage: 1.5+ MB

# %% [markdown]
# #####  Data overview

# %%
cust_demo.head()
# Out:
#       ID account_type gender  age  Income  Emp_Tenure_Years  Tenure_with_Bank  \
# 0  19427      current      M   63  MEDIUM              30.1                10
# 1  16150      current      M   36  MEDIUM              14.4                10
# 2  11749      current      F   28  MEDIUM               4.8                10
# 3  11635      current      M   32  MEDIUM               9.6                 2
# 4   8908      current      M   32    HIGH              12.0                 7
#
#    region_code  NetBanking_Flag  Avg_days_between_transaction
# 0        628.0                1                           5.0
# 1        656.0                0                          12.0
# 2        314.0                1                          13.0
# 3        614.0                1                          19.0
# 4        750.0                1                          18.0

# %%
cust_behav.head()
# Out:
#       ID  cc_cons_apr  dc_cons_apr  cc_cons_may  dc_cons_may  cc_cons_jun  \
# 0  17051      3412.60      2909.34      1077.36      3084.50      4615.97
# 1  11491     18133.76      3877.00      6123.78      5597.43     64620.00
# 2   7433      6363.65       735.49      8799.00     13768.00     38266.00
# 3  14606     12765.66      4429.16     16745.86      6360.00     29063.97
# 4   8381     27819.70      1944.00      7006.50      2228.50      1096.25
#
#    dc_cons_jun  cc_count_apr  cc_count_may  cc_count_jun  ...  \
# 0       6693.0          19.0            10             2  ...
# 1       6117.0           4.0            60             1  ...
# 2       2638.0           2.0            83            47  ...
# 3       3711.0          12.0             2            16  ...
# 4       1065.0          15.0            13            61  ...
#
#    credit_count_may  debit_count_may  max_credit_amount_may  debit_amount_jun  \
# 0                 1              108                97916.0          45253.64
# 1                 1                4                25125.0          12912.33
# 2                70               11                38546.0          93567.51
# 3                43                1               180315.0         176394.48
# 4                 2               14                13480.0           3167.00
#
#    credit_amount_jun  credit_count_jun  debit_count_jun  \
# 0           47635.00                 2               18
# 1           18369.00                 3               49
# 2           26713.00                47               49
# 3           35062.74                 3               37
# 4           19056.00                 2               15
#
#    max_credit_amount_jun  loan_enq  emi_active
# 0                19947.0         Y     3448.84
# 1                20585.0         Y     3812.69
# 2                13950.0         Y     9432.90
# 3                37018.0         Y      144.61
# 4                24274.0         Y     1887.89
#
# [5 rows x 39 columns]

# %%
cust_con.head()
# Out:
#       ID  cc_cons
# 0  12554  20014.0
# 1  17645  10173.0
# 2   7604  16095.0
# 3   1590   7707.0
# 4  16556  96408.0

# %% [markdown]
# ## Exploratory Data Analysis (EDA)
# - Check for missing values and handle them appropriately.
# - Identify outliers and distribution of key variables.
# - Analyze spending patterns across demographics.

# %% [markdown]
# ###### Merging Data

# %%
cust_bhave_demo =pd.merge(left=cust_demo, right=cust_behav, on=["ID","ID"], how="inner")

# %%
customer = pd.merge(left=cust_bhave_demo, right=cust_con, on=["ID","ID"], how="inner")

# %%
customer
# Out:
#           ID account_type gender  age  Income  Emp_Tenure_Years  \
# 0      19427      current      M   63  MEDIUM              30.1
# 1      16150      current      M   36  MEDIUM              14.4
# 2      11749      current      F   28  MEDIUM               4.8
# 3      11635      current      M   32  MEDIUM               9.6
# 4       8908      current      M   32    HIGH              12.0
# ...      ...          ...    ...  ...     ...               ...
# 19995   1270      current      F   66  MEDIUM              32.2
# 19996  15992      current      M   53  MEDIUM              19.8
# 19997   7081      current      F   66  MEDIUM              18.4
# 19998   6821      current      M   32     LOW               6.0
# 19999  13730      current      F  118     LOW              78.4
#
#        Tenure_with_Bank  region_code  NetBanking_Flag  \
# 0                    10        628.0                1
# 1                    10        656.0                0
# 2                    10        314.0                1
# 3                     2        614.0                1
# 4                     7        750.0                1
# ...                 ...          ...              ...
# 19995                 6        354.0                1
# 19996                 5        809.0                0
# 19997                 1        466.0                0
# 19998                 8        619.0                0
# 19999                 7        882.0                1
#
#        Avg_days_between_transaction  ...  debit_count_may  \
# 0                               5.0  ...               14
# 1                              12.0  ...               63
# 2                              13.0  ...               82
# 3                              19.0  ...               78
# 4                              18.0  ...              171
# ...                             ...  ...              ...
# 19995                           7.0  ...                8
# 19996                          14.0  ...               11
# 19997                          10.0  ...              171
# 19998                          17.0  ...               82
# 19999                          10.0  ...                8
#
#        max_credit_amount_may  debit_amount_jun  credit_amount_jun  \
# 0                    20770.0          44884.90          369000.75
# 1                    78627.0          91073.84          243182.32
# 2                     1260.0          96552.00           35467.00
# 3                    23332.0          18250.00           87204.35
# 4                    41672.0          83525.75           83992.00
# ...                      ...               ...                ...
# 19995                24438.0         153772.21           31284.00
# 19996               213000.0          18098.47           93108.00
# 19997                34327.0          32198.63           46800.00
# 19998                51929.0          27334.14           20201.00
# 19999                32431.0          23464.59           38503.00
#
#        credit_count_jun  debit_count_jun  max_credit_amount_jun  loan_enq  \
# 0                    40               96                46088.0         Y
# 1                     7               12                17953.0         Y
# 2                    16               42                41121.0         Y
# 3                     2               10                32003.0         Y
# 4                    21               12                 9626.0         Y
# ...                 ...              ...                    ...       ...
# 19995                 3               38                42872.0         Y
# 19996                43               11                36747.0         Y
# 19997                 3               38                18810.0         Y
# 19998                47               80                11443.0         Y
# 19999                 5               42                47504.0         Y
#
#        emi_active  cc_cons
# 0         2646.72      NaN
# 1         5469.79      NaN
# 2         7207.85      NaN
# 3          591.34      NaN
# 4         2621.39      NaN
# ...           ...      ...
# 19995     6334.20      NaN
# 19996   102216.02      NaN
# 19997     1930.19      NaN
# 19998    24499.91      NaN
# 19999     5311.54      NaN
#
# [20000 rows x 49 columns]

# %% [markdown]
# ##### Data Cleaning And Pre Modeling

# %%
customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 49 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ID                            20000 non-null  int64
#  1   account_type                  19999 non-null  object
#  2   gender                        19999 non-null  object
#  3   age                           20000 non-null  int64
#  4   Income                        19999 non-null  object
#  5   Emp_Tenure_Years              20000 non-null  float64
#  6   Tenure_with_Bank              20000 non-null  int64
#  7   region_code                   19999 non-null  float64
#  8   NetBanking_Flag               20000 non-null  int64
#  9   Avg_days_between_transaction  19997 non-null  float64
#  10  cc_cons_apr                   20000 non-null  float64
#  11  dc_cons_apr                   20000 non-null  float64
#  12  cc_cons_may                   19999 non-null  float64
#  13  dc_cons_may                   20000 non-null  float64
#  14  cc_cons_jun                   20000 non-null  float64
#  15  dc_cons_jun                   19999 non-null  float64
#  16  cc_count_apr                  19999 non-null  float64
#  17  cc_count_may                  20000 non-null  int64
#  18  cc_count_jun                  20000 non-null  int64
#  19  dc_count_apr                  20000 non-null  int64
#  20  dc_count_may                  20000 non-null  int64
#  21  dc_count_jun                  20000 non-null  int64
#  22  card_lim                      20000 non-null  int64
#  23  personal_loan_active          20000 non-null  int64
#  24  vehicle_loan_active           20000 non-null  int64
#  25  personal_loan_closed          19999 non-null  float64
#  26  vehicle_loan_closed           20000 non-null  int64
#  27  investment_1                  20000 non-null  float64
#  28  investment_2                  20000 non-null  float64
#  29  investment_3                  19998 non-null  float64
#  30  investment_4                  20000 non-null  float64
#  31  debit_amount_apr              20000 non-null  float64
#  32  credit_amount_apr             20000 non-null  float64
#  33  debit_count_apr               19999 non-null  float64
#  34  credit_count_apr              20000 non-null  int64
#  35  max_credit_amount_apr         20000 non-null  float64
#  36  debit_amount_may              20000 non-null  float64
#  37  credit_amount_may             20000 non-null  float64
#  38  credit_count_may              20000 non-null  int64
#  39  debit_count_may               20000 non-null  int64
#  40  max_credit_amount_may         20000 non-null  float64
#  41  debit_amount_jun              20000 non-null  float64
#  42  credit_amount_jun             20000 non-null  float64
#  43  credit_count_jun              20000 non-null  int64
#  44  debit_count_jun               20000 non-null  int64
#  45  max_credit_amount_jun         20000 non-null  float64
#  46  loan_enq                      19998 non-null  object
#  47  emi_active                    19999 non-null  float64
#  48  cc_cons                       15000 non-null  float64
# dtypes: float64(27), int64(18), object(4)
# memory usage: 7.5+ MB

# %%
customer.describe().T
# Out:
#                                 count           mean           std       min  \
# ID                            20000.0    9999.500000  5.773647e+03      0.00
# age                           20000.0      47.672300  3.035977e+01     25.00
# Emp_Tenure_Years              20000.0      15.217250  2.048145e+01      0.50
# Tenure_with_Bank              20000.0       5.496050  2.870452e+00      1.00
# region_code                   19999.0     598.959348  2.201052e+02    123.00
# NetBanking_Flag               20000.0       0.718000  4.499846e-01      0.00
# Avg_days_between_transaction  19997.0      11.044757  5.480552e+00      2.00
# cc_cons_apr                   20000.0   17856.990922  2.515888e+04    253.00
# dc_cons_apr                   20000.0    8130.453414  1.457219e+04     19.35
# cc_cons_may                   19999.0   16188.364717  2.651068e+04    157.00
# dc_cons_may                   20000.0    7702.427191  1.789273e+04     22.00
# cc_cons_jun                   20000.0   12135.806020  1.879098e+04     65.00
# dc_cons_jun                   19999.0    7109.708341  1.331394e+04     62.00
# cc_count_apr                  19999.0      41.611631  9.783547e+01      1.00
# cc_count_may                  20000.0      33.569100  5.031692e+01      1.00
# cc_count_jun                  20000.0      41.470200  4.682566e+01      1.00
# dc_count_apr                  20000.0      17.071700  1.928532e+01      1.00
# dc_count_may                  20000.0      14.067750  1.715780e+01      1.00
# dc_count_jun                  20000.0      30.481150  2.933219e+01      1.00
# card_lim                      20000.0  278346.396100  1.807583e+05      0.00
# personal_loan_active          20000.0       1.000000  0.000000e+00      1.00
# vehicle_loan_active           20000.0       1.000000  0.000000e+00      1.00
# personal_loan_closed          19999.0       1.000000  0.000000e+00      1.00
# vehicle_loan_closed           20000.0       1.000000  0.000000e+00      1.00
# investment_1                  20000.0  590898.109444  2.937387e+06      0.30
# investment_2                  20000.0  232952.031688  4.075202e+05      3.00
# investment_3                  19998.0   44605.654868  8.850497e+04    462.00
# investment_4                  20000.0    3495.439932  7.369511e+03 -12179.00
# debit_amount_apr              20000.0   68644.997682  1.138021e+05      4.01
# credit_amount_apr             20000.0   79686.846292  1.833605e+05     61.38
# debit_count_apr               19999.0      36.240362  3.057426e+01      0.00
# credit_count_apr              20000.0      11.250750  1.265654e+01      0.00
# max_credit_amount_apr         20000.0   54418.935199  1.964095e+05      1.00
# debit_amount_may              20000.0   65306.354726  1.016961e+05     28.20
# credit_amount_may             20000.0   82937.068802  1.714761e+05     10.61
# credit_count_may              20000.0      11.919000  1.685576e+01      0.00
# debit_count_may               20000.0      40.974850  4.056120e+01      0.00
# max_credit_amount_may         20000.0   58207.985138  2.085914e+05      0.25
# debit_amount_jun              20000.0   78122.797159  2.448983e+05      5.23
# credit_amount_jun             20000.0   78816.927608  1.569872e+05     11.88
# credit_count_jun              20000.0      19.905450  2.705532e+01      1.00
# debit_count_jun               20000.0      44.529100  3.508045e+01      0.00
# max_credit_amount_jun         20000.0   52849.847571  1.343175e+05      0.06
# emi_active                    19999.0   15398.868773  1.202541e+05      0.00
# cc_cons                       15000.0   55157.729867  9.767097e+04      0.00
#
#                                      25%          50%          75%  \
# ID                              4999.750    9999.5000   14999.2500
# age                               33.000      40.0000      53.0000
# Emp_Tenure_Years                   5.100       9.9000      18.0000
# Tenure_with_Bank                   3.000       6.0000       8.0000
# region_code                      424.000     623.0000     799.0000
# NetBanking_Flag                    0.000       1.0000       1.0000
# Avg_days_between_transaction       6.000      11.0000      16.0000
# cc_cons_apr                     4377.000   10214.6425   21189.0000
# dc_cons_apr                     1624.650    3964.7500    9339.0200
# cc_cons_may                     3635.910    8635.2300   18655.3050
# dc_cons_may                     1634.260    3791.7200    8263.5900
# cc_cons_jun                     2999.075    6656.8000   14195.7275
# dc_cons_jun                     1361.100    3326.0000    7458.8200
# cc_count_apr                       5.000      10.0000      44.0000
# cc_count_may                       8.000      23.0000      43.0000
# cc_count_jun                      10.000      35.0000      61.0000
# dc_count_apr                       2.000       7.0000      25.0000
# dc_count_may                       2.000       5.0000      21.0000
# dc_count_jun                       4.000      17.0000      54.0000
# card_lim                      124000.000  272000.0000  401000.0000
# personal_loan_active               1.000       1.0000       1.0000
# vehicle_loan_active                1.000       1.0000       1.0000
# personal_loan_closed               1.000       1.0000       1.0000
# vehicle_loan_closed                1.000       1.0000       1.0000
# investment_1                    6030.650   44331.8100  161704.0000
# investment_2                   38928.000  110135.8600  245000.0000
# investment_3                    2214.000   13873.0000   48950.0000
# investment_4                       0.000    2351.0000    6885.0000
# debit_amount_apr               23206.530   41681.1400   76553.2825
# credit_amount_apr              26764.000   46998.0000   85740.0000
# debit_count_apr                   11.000      32.0000      52.0000
# credit_count_apr                   2.000       4.0000      19.0000
# max_credit_amount_apr          20613.000   31908.0000   52503.0000
# debit_amount_may               20816.110   38116.0000   74063.3900
# credit_amount_may              25210.750   48137.1850   94476.5575
# credit_count_may                   2.000       4.0000      11.0000
# debit_count_may                   11.000      23.0000      69.0000
# max_credit_amount_may          20202.250   31496.5000   56421.0000
# debit_amount_jun               25763.110   45725.0500   85296.5300
# credit_amount_jun              24920.080   46183.0000   86020.0000
# credit_count_jun                   4.000       7.0000      21.0000
# debit_count_jun                   12.000      37.0000      73.0000
# max_credit_amount_jun          18964.500   30250.0000   53449.0000
# emi_active                      1545.940    3934.6600    9376.3900
# cc_cons                         6768.000   13364.0000   20105.7500
#
#                                       max
# ID                               19999.00
# age                                223.00
# Emp_Tenure_Years                   203.00
# Tenure_with_Bank                    10.00
# region_code                        974.00
# NetBanking_Flag                      1.00
# Avg_days_between_transaction        20.00
# cc_cons_apr                     441031.33
# dc_cons_apr                     229255.00
# cc_cons_may                    1117246.31
# dc_cons_may                     911223.49
# cc_cons_jun                     382914.10
# dc_cons_jun                     233384.00
# cc_count_apr                       531.00
# cc_count_may                       601.00
# cc_count_jun                       653.00
# dc_count_apr                        82.00
# dc_count_may                        71.00
# dc_count_jun                        98.00
# card_lim                       1000000.00
# personal_loan_active                 1.00
# vehicle_loan_active                  1.00
# personal_loan_closed                 1.00
# vehicle_loan_closed                  1.00
# investment_1                  65977430.00
# investment_2                   5000000.00
# investment_3                    610000.00
# investment_4                     35346.00
# debit_amount_apr               5156863.79
# credit_amount_apr             10592125.00
# debit_count_apr                    147.00
# credit_count_apr                    78.00
# max_credit_amount_apr         12029154.00
# debit_amount_may               4252567.00
# credit_amount_may             10601749.00
# credit_count_may                    71.00
# debit_count_may                    171.00
# max_credit_amount_may         10000000.00
# debit_amount_jun              26429152.75
# credit_amount_jun              6611953.00
# credit_count_jun                   117.00
# debit_count_jun                    133.00
# max_credit_amount_jun          5200000.00
# emi_active                     7447125.13
# cc_cons                         408382.00

# %%
# cc_cons_x and cc_cons_y have outliers

# %%
customer.isnull().sum()
# Out:
# ID                                 0
# account_type                       1
# gender                             1
# age                                0
# Income                             1
# Emp_Tenure_Years                   0
# Tenure_with_Bank                   0
# region_code                        1
# NetBanking_Flag                    0
# Avg_days_between_transaction       3
# cc_cons_apr                        0
# dc_cons_apr                        0
# cc_cons_may                        1
# dc_cons_may                        0
# cc_cons_jun                        0
# dc_cons_jun                        1
# cc_count_apr                       1
# cc_count_may                       0
# cc_count_jun                       0
# dc_count_apr                       0
# dc_count_may                       0
# dc_count_jun                       0
# card_lim                           0
# personal_loan_active               0
# vehicle_loan_active                0
# personal_loan_closed               1
# vehicle_loan_closed                0
# investment_1                       0
# investment_2                       0
# investment_3                       2
# investment_4                       0
# debit_amount_apr                   0
# credit_amount_apr                  0
# debit_count_apr                    1
# credit_count_apr                   0
# max_credit_amount_apr              0
# debit_amount_may                   0
# credit_amount_may                  0
# credit_count_may                   0
# debit_count_may                    0
# max_credit_amount_may              0
# debit_amount_jun                   0
# credit_amount_jun                  0
# credit_count_jun                   0
# debit_count_jun                    0
# max_credit_amount_jun              0
# loan_enq                           2
# emi_active                         1
# cc_cons                         5000
# dtype: int64

# %%
## dropping loan_enq , since it is a categorical variable and all values are same "Y"
customer.drop(columns='loan_enq', inplace=True)

# %%
customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 48 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ID                            20000 non-null  int64
#  1   account_type                  19999 non-null  object
#  2   gender                        19999 non-null  object
#  3   age                           20000 non-null  int64
#  4   Income                        19999 non-null  object
#  5   Emp_Tenure_Years              20000 non-null  float64
#  6   Tenure_with_Bank              20000 non-null  int64
#  7   region_code                   19999 non-null  float64
#  8   NetBanking_Flag               20000 non-null  int64
#  9   Avg_days_between_transaction  19997 non-null  float64
#  10  cc_cons_apr                   20000 non-null  float64
#  11  dc_cons_apr                   20000 non-null  float64
#  12  cc_cons_may                   19999 non-null  float64
#  13  dc_cons_may                   20000 non-null  float64
#  14  cc_cons_jun                   20000 non-null  float64
#  15  dc_cons_jun                   19999 non-null  float64
#  16  cc_count_apr                  19999 non-null  float64
#  17  cc_count_may                  20000 non-null  int64
#  18  cc_count_jun                  20000 non-null  int64
#  19  dc_count_apr                  20000 non-null  int64
#  20  dc_count_may                  20000 non-null  int64
#  21  dc_count_jun                  20000 non-null  int64
#  22  card_lim                      20000 non-null  int64
#  23  personal_loan_active          20000 non-null  int64
#  24  vehicle_loan_active           20000 non-null  int64
#  25  personal_loan_closed          19999 non-null  float64
#  26  vehicle_loan_closed           20000 non-null  int64
#  27  investment_1                  20000 non-null  float64
#  28  investment_2                  20000 non-null  float64
#  29  investment_3                  19998 non-null  float64
#  30  investment_4                  20000 non-null  float64
#  31  debit_amount_apr              20000 non-null  float64
#  32  credit_amount_apr             20000 non-null  float64
#  33  debit_count_apr               19999 non-null  float64
#  34  credit_count_apr              20000 non-null  int64
#  35  max_credit_amount_apr         20000 non-null  float64
#  36  debit_amount_may              20000 non-null  float64
#  37  credit_amount_may             20000 non-null  float64
#  38  credit_count_may              20000 non-null  int64
#  39  debit_count_may               20000 non-null  int64
#  40  max_credit_amount_may         20000 non-null  float64
#  41  debit_amount_jun              20000 non-null  float64
#  42  credit_amount_jun             20000 non-null  float64
#  43  credit_count_jun              20000 non-null  int64
#  44  debit_count_jun               20000 non-null  int64
#  45  max_credit_amount_jun         20000 non-null  float64
#  46  emi_active                    19999 non-null  float64
#  47  cc_cons                       15000 non-null  float64
# dtypes: float64(27), int64(18), object(3)
# memory usage: 7.3+ MB

# %%
# Splitting Continuous Variables and Categorical Variables
customer.select_dtypes(include=['int64','float64']).columns
# Out:
# Index(['ID', 'age', 'Emp_Tenure_Years', 'Tenure_with_Bank', 'region_code',
#        'NetBanking_Flag', 'Avg_days_between_transaction', 'cc_cons_apr',
#        'dc_cons_apr', 'cc_cons_may', 'dc_cons_may', 'cc_cons_jun',
#        'dc_cons_jun', 'cc_count_apr', 'cc_count_may', 'cc_count_jun',
#        'dc_count_apr', 'dc_count_may', 'dc_count_jun', 'card_lim',
#        'personal_loan_active', 'vehicle_loan_active', 'personal_loan_closed',
#        'vehicle_loan_closed', 'investment_1', 'investment_2', 'investment_3',
#        'investment_4', 'debit_amount_apr', 'credit_amount_apr',
#        'debit_count_apr', 'credit_count_apr', 'max_credit_amount_apr',
#        'debit_amount_may', 'credit_amount_may', 'credit_count_may',
#        'debit_count_may', 'max_credit_amount_may', 'debit_amount_jun',
#        'credit_amount_jun', 'credit_count_jun', 'debit_count_jun',
#        'max_credit_amount_jun', 'emi_active', 'cc_cons'],
#       dtype='object')

# %%
continuous = ['age', 'Emp_Tenure_Years', 'Tenure_with_Bank','Avg_days_between_transaction', 'cc_cons_apr',
       'dc_cons_apr', 'cc_cons_may', 'dc_cons_may', 'cc_cons_jun',
       'dc_cons_jun', 'cc_count_apr', 'cc_count_may', 'cc_count_jun',
       'dc_count_apr', 'dc_count_may', 'dc_count_jun','investment_1', 'investment_2', 'investment_3',
       'investment_4', 'debit_amount_apr', 'credit_amount_apr',
       'debit_count_apr', 'credit_count_apr', 'max_credit_amount_apr',
       'debit_amount_may', 'credit_amount_may', 'credit_count_may',
       'debit_count_may', 'max_credit_amount_may', 'debit_amount_jun',
       'credit_amount_jun', 'credit_count_jun', 'debit_count_jun',
       'max_credit_amount_jun','emi_active', 'cc_cons']
cat_col = ['account_type', 'gender','Income','region_code','NetBanking_Flag']

# %%
cont_customer = customer.loc[:,continuous]

# %%
cat_customer = customer.loc[:,cat_col]

# %%
# Creating function for summary and ouliers

# %%
def cont_var_summary( x ):
    # frequancy and missings
    x_total = x.shape[0]
    x_miss = x.isna().sum()
    perc_miss = x_miss * 100 / x_total
    
    # outliers 
    q1 = x.quantile(0.25)
    q3 = x.quantile(0.75)
    iqr = q3 - q1
    lc_iqr = q1 - 1.5 * iqr
    uc_iqr = q3 + 1.5 * iqr
    
    return pd.Series( [ x.dtype, x.nunique(), x_total, x.count(), x_miss, perc_miss,
                       x.sum(), x.mean(), x.std(), x.var(), 
                       lc_iqr, uc_iqr, 
                       x.min(), x.quantile(0.01), x.quantile(0.05), x.quantile(0.10), 
                       x.quantile(0.25), x.quantile(0.5), x.quantile(0.75), 
                       x.quantile(0.90), x.quantile(0.95), x.quantile(0.99), x.max() ], 
                     
                    index = ['dtype', 'cardinality', 'x_tot', 'x', 'nmiss', 'perc_miss',
                             'sum', 'mean', 'std', 'var',
                        'lc_iqr', 'uc_iqr',
                        'min', 'p1', 'p5', 'p10', 'p25', 'p50', 'p75', 'p90', 'p95', 'p99', 'max'])

# %%
cont_customer.apply(cont_var_summary)
# Out:
#                     age Emp_Tenure_Years Tenure_with_Bank  \
# dtype             int64          float64            int64
# cardinality          43              270               10
# x_tot             20000            20000            20000
# x                 20000            20000            20000
# nmiss                 0                0                0
# perc_miss           0.0              0.0              0.0
# sum              953446         304345.0           109921
# mean            47.6723         15.21725          5.49605
# std           30.359771        20.481455         2.870452
# var          921.715698       419.489979         8.239496
# lc_iqr              3.0           -14.25             -4.5
# uc_iqr             83.0            37.35             15.5
# min                  25              0.5                1
# p1                 27.0              0.9              1.0
# p5                 28.0              1.7              1.0
# p10                29.0              2.7              2.0
# p25                33.0              5.1              3.0
# p50                40.0              9.9              6.0
# p75                53.0             18.0              8.0
# p90                64.0             31.5             10.0
# p95                66.0             40.0             10.0
# p99               222.0            121.2             10.0
# max                 223            203.0               10
#
#             Avg_days_between_transaction       cc_cons_apr       dc_cons_apr  \
# dtype                            float64           float64           float64
# cardinality                           19              8459              3861
# x_tot                              20000             20000             20000
# x                                  19997             20000             20000
# nmiss                                  3                 0                 0
# perc_miss                          0.015               0.0               0.0
# sum                             220862.0      357139818.44      162609068.27
# mean                           11.044757      17856.990922       8130.453414
# std                             5.480552      25158.878234      14572.188829
# var                            30.036454  632969153.988079  212348687.260089
# lc_iqr                              -9.0          -20841.0         -9946.905
# uc_iqr                              31.0           46407.0         20910.575
# min                                  2.0             253.0             19.35
# p1                                   2.0          641.9886          153.1286
# p5                                   2.0            1219.0             378.0
# p10                                  3.0            1908.0            643.85
# p25                                  6.0            4377.0           1624.65
# p50                                 11.0        10214.6425           3964.75
# p75                                 16.0           21189.0           9339.02
# p90                                 19.0           40640.9         18443.691
# p95                                 20.0         59106.728           27835.0
# p99                                 20.0          125259.5          64470.75
# max                                 20.0         441031.33          229255.0
#
#                   cc_cons_may       dc_cons_may       cc_cons_jun  \
# dtype                 float64           float64           float64
# cardinality              8504              4053              7347
# x_tot                   20000             20000             20000
# x                       19999             20000             20000
# nmiss                       1                 0                 0
# perc_miss               0.005               0.0               0.0
# sum              323751105.97      154048543.82      242716120.41
# mean             16188.364717       7702.427191       12135.80602
# std              26510.681596        17892.7318      18790.984789
# var          702816238.690255  320149851.281652  353101109.329598
# lc_iqr            -18893.1825         -8309.735      -13795.90375
# uc_iqr             41184.3975         18207.585       30990.70625
# min                     157.0              22.0              65.0
# p1                     509.49             152.1             334.0
# p5                   1035.774            410.97           825.101
# p10                  1666.328             731.0           1367.52
# p25                   3635.91           1634.26          2999.075
# p50                   8635.23           3791.72            6656.8
# p75                 18655.305           8263.59        14195.7275
# p90                 36139.588          16144.76        26791.1665
# p95                  53962.38           25584.0        39979.6775
# p99                125735.433        65963.0603          90310.08
# max                1117246.31         911223.49          382914.1
#
#                   dc_cons_jun  ... credit_count_may debit_count_may  \
# dtype                 float64  ...            int64           int64
# cardinality              3019  ...               31              57
# x_tot                   20000  ...            20000           20000
# x                       19999  ...            20000           20000
# nmiss                       1  ...                0               0
# perc_miss               0.005  ...              0.0             0.0
# sum              142187057.12  ...           238380          819497
# mean              7109.708341  ...           11.919        40.97485
# std              13313.935609  ...         16.85576       40.561202
# var          177260881.388224  ...       284.116645     1645.211078
# lc_iqr               -7785.48  ...            -11.5           -76.0
# uc_iqr                16605.4  ...             24.5           156.0
# min                      62.0  ...                0               0
# p1                     190.95  ...              0.0             1.0
# p5                      390.0  ...              1.0             4.0
# p10                     607.0  ...              1.0             6.0
# p25                    1361.1  ...              2.0            11.0
# p50                    3326.0  ...              4.0            23.0
# p75                   7458.82  ...             11.0            69.0
# p90                   15689.0  ...             43.0            84.0
# p95                  24252.88  ...             47.0           108.0
# p99                   72564.0  ...             70.0           171.0
# max                  233384.0  ...               71             171
#
#             max_credit_amount_may    debit_amount_jun   credit_amount_jun  \
# dtype                     float64             float64             float64
# cardinality                  5299                8632                8311
# x_tot                       20000               20000               20000
# x                           20000               20000               20000
# nmiss                           0                   0                   0
# perc_miss                     0.0                 0.0                 0.0
# sum                 1164159702.76       1562455943.19       1576338552.15
# mean                 58207.985138        78122.797159        78816.927608
# std                 208591.362703       244898.308732       156987.241764
# var            43510356594.345634  59975181619.710663  24644994076.810459
# lc_iqr                 -34125.875           -63537.02            -66729.8
# uc_iqr                 110749.125           174596.66           177669.88
# min                          0.25                5.23               11.88
# p1                         120.34              1077.0               296.0
# p5                         5675.0              6972.0              4020.9
# p10                       12003.0           12573.958            11509.04
# p25                      20202.25            25763.11            24920.08
# p50                       31496.5            45725.05             46183.0
# p75                       56421.0            85296.53             86020.0
# p90                      103500.0           151821.74           158148.58
# p95                      157048.0         220638.7625         234766.7625
# p99                      385963.0           535233.77            534467.0
# max                    10000000.0         26429152.75           6611953.0
#
#             credit_count_jun debit_count_jun max_credit_amount_jun  \
# dtype                  int64           int64               float64
# cardinality               39              66                  5833
# x_tot                  20000           20000                 20000
# x                      20000           20000                 20000
# nmiss                      0               0                     0
# perc_miss                0.0             0.0                   0.0
# sum                   398109          890582         1056996951.42
# mean                19.90545         44.5291          52849.847571
# std                27.055323       35.080453         134317.525107
# var                731.99051     1230.638185    18041197550.945358
# lc_iqr                 -21.5           -79.5             -32762.25
# uc_iqr                  46.5           164.5             105175.75
# min                        1               0                  0.06
# p1                       1.0             0.0                 160.0
# p5                       2.0             2.0                1679.5
# p10                      2.0             7.0               11200.0
# p25                      4.0            12.0               18964.5
# p50                      7.0            37.0               30250.0
# p75                     21.0            73.0               53449.0
# p90                     58.0           103.0              100183.0
# p95                     94.0           106.0             150006.83
# p99                    117.0           124.0              377905.0
# max                      117             133             5200000.0
#
#                      emi_active            cc_cons
# dtype                   float64            float64
# cardinality                5940              12260
# x_tot                     20000              20000
# x                         19999              15000
# nmiss                         1               5000
# perc_miss                 0.005               25.0
# sum                 307961976.6        827365948.0
# mean               15398.868773       55157.729867
# std               120254.075769       97670.972252
# var          14461042739.004244  9539618820.721489
# lc_iqr               -10199.735         -13238.625
# uc_iqr                21122.065          40112.375
# min                         0.0                0.0
# p1                       26.739             271.99
# p5                       197.95            1290.85
# p10                      461.06             2633.6
# p25                     1545.94             6768.0
# p50                     3934.66            13364.0
# p75                     9376.39           20105.75
# p90                   19715.252           219688.7
# p95                    36148.07           309852.0
# p99                  155041.219          395290.55
# max                  7447125.13           408382.0
#
# [23 rows x 37 columns]

# %%
customer[['account_type', 'gender','Income']].describe()
# Out:
#        account_type gender  Income
# count         19999  19999   19999
# unique            2      2       3
# top         current      M  MEDIUM
# freq          16925  17287   12774

# %% [markdown]
# ##### Outlier Treatment

# %%
cont_customer.apply( lambda x: x.clip(lower = x.quantile(0.01),upper = x.quantile(0.99),inplace=True))
# Out:
# age                             None
# Emp_Tenure_Years                None
# Tenure_with_Bank                None
# Avg_days_between_transaction    None
# cc_cons_apr                     None
# dc_cons_apr                     None
# cc_cons_may                     None
# dc_cons_may                     None
# cc_cons_jun                     None
# dc_cons_jun                     None
# cc_count_apr                    None
# cc_count_may                    None
# cc_count_jun                    None
# dc_count_apr                    None
# dc_count_may                    None
# dc_count_jun                    None
# investment_1                    None
# investment_2                    None
# investment_3                    None
# investment_4                    None
# debit_amount_apr                None
# credit_amount_apr               None
# debit_count_apr                 None
# credit_count_apr                None
# max_credit_amount_apr           None
# debit_amount_may                None
# credit_amount_may               None
# credit_count_may                None
# debit_count_may                 None
# max_credit_amount_may           None
# debit_amount_jun                None
# credit_amount_jun               None
# credit_count_jun                None
# debit_count_jun                 None
# max_credit_amount_jun           None
# emi_active                      None
# cc_cons                         None
# dtype: object

# %%
cont_customer.apply(cont_var_summary)
# Out:
#                     age Emp_Tenure_Years Tenure_with_Bank  \
# dtype             int64          float64            int64
# cardinality          41              246               10
# x_tot             20000            20000            20000
# x                 20000            20000            20000
# nmiss                 0                0                0
# perc_miss           0.0              0.0              0.0
# sum              953579         294931.2           109921
# mean           47.67895         14.74656          5.49605
# std           30.311294        17.040411         2.870452
# var          918.774516       290.375592         8.239496
# lc_iqr              3.0           -14.25             -4.5
# uc_iqr             83.0            37.35             15.5
# min                  27              0.9                1
# p1                 27.0              0.9              1.0
# p5                 28.0              1.7              1.0
# p10                29.0              2.7              2.0
# p25                33.0              5.1              3.0
# p50                40.0              9.9              6.0
# p75                53.0             18.0              8.0
# p90                64.0             31.5             10.0
# p95                66.0             40.0             10.0
# p99               222.0            121.2             10.0
# max                 222            121.2               10
#
#             Avg_days_between_transaction       cc_cons_apr       dc_cons_apr  \
# dtype                            float64           float64           float64
# cardinality                           19              8302              3789
# x_tot                              20000             20000             20000
# x                                  19997             20000             20000
# nmiss                                  3                 0                 0
# perc_miss                          0.015               0.0               0.0
# sum                             220862.0      346146525.37      152855585.51
# mean                           11.044757      17307.326269       7642.779275
# std                             5.480552      21180.687109      10456.109254
# var                            30.036454  448621506.394323  109330220.730953
# lc_iqr                              -9.0          -20841.0         -9946.905
# uc_iqr                              31.0           46407.0         20910.575
# min                                  2.0          641.9886          153.1286
# p1                                   2.0        641.999886        153.139886
# p5                                   2.0            1219.0             378.0
# p10                                  3.0            1908.0            643.85
# p25                                  6.0            4377.0           1624.65
# p50                                 11.0        10214.6425           3964.75
# p75                                 16.0           21189.0           9339.02
# p90                                 19.0           40640.9         18443.691
# p95                                 20.0         59106.728           27835.0
# p99                                 20.0          125259.5          64470.75
# max                                 20.0          125259.5          64470.75
#
#                   cc_cons_may       dc_cons_may       cc_cons_jun  \
# dtype                 float64           float64           float64
# cardinality              8345              3972              7205
# x_tot                   20000             20000             20000
# x                       19999             20000             20000
# nmiss                       1                 0                 0
# perc_miss               0.005               0.0               0.0
# sum              311485406.43      143831037.93  232619464.114999
# mean             15575.049074       7191.551896      11630.973206
# std              20400.815735      10328.490113      14689.082389
# var          416193282.644561  106677708.019133  215769141.419008
# lc_iqr            -18893.1825         -8309.735      -13795.90375
# uc_iqr             41184.3975         18207.585       30990.70625
# min                    509.49             152.1             334.0
# p1                   509.4998             152.1             334.0
# p5                   1035.774            410.97           825.101
# p10                  1666.328             731.0           1367.52
# p25                   3635.91           1634.26          2999.075
# p50                   8635.23           3791.72            6656.8
# p75                 18655.305           8263.59        14195.7275
# p90                 36139.588          16144.76        26791.1665
# p95                  53962.38           25584.0        39979.6775
# p99              125720.79866      65962.010603        90290.2008
# max                125735.433        65963.0603          90310.08
#
#                   dc_cons_jun  ... credit_count_may debit_count_may  \
# dtype                 float64  ...            int64           int64
# cardinality              2951  ...               30              56
# x_tot                   20000  ...            20000           20000
# x                       19999  ...            20000           20000
# nmiss                       1  ...                0               0
# perc_miss               0.005  ...              0.0             0.0
# sum              135690695.56  ...           238356          819575
# mean              6784.874022  ...          11.9178        40.97875
# std              10609.560566  ...        16.851589       40.557309
# var          112562775.406872  ...       283.976042     1644.895343
# lc_iqr               -7785.48  ...            -11.5           -76.0
# uc_iqr                16605.4  ...             24.5           156.0
# min                    190.95  ...                0               1
# p1                    190.999  ...              0.0             1.0
# p5                      390.0  ...              1.0             4.0
# p10                     607.0  ...              1.0             6.0
# p25                    1361.1  ...              2.0            11.0
# p50                    3326.0  ...              4.0            23.0
# p75                   7458.82  ...             11.0            69.0
# p90                   15689.0  ...             43.0            84.0
# p95                  24252.88  ...             47.0           108.0
# p99                   72564.0  ...             70.0           171.0
# max                   72564.0  ...               70             171
#
#             max_credit_amount_may   debit_amount_jun  credit_amount_jun  \
# dtype                     float64            float64            float64
# cardinality                  5196               8476               8150
# x_tot                       20000              20000              20000
# x                           20000              20000              20000
# nmiss                           0                  0                  0
# perc_miss                     0.0                0.0                0.0
# sum                 1012022855.42      1425114478.53      1456158777.81
# mean                 50601.142771       71255.723927       72807.938891
# std                  59226.918134       81596.204599       85133.417139
# var             3507827831.614031  6657940604.970504  7247698713.828243
# lc_iqr                 -34125.875          -63537.02           -66729.8
# uc_iqr                 110749.125          174596.66          177669.88
# min                        120.34             1077.0              296.0
# p1                         120.34             1077.0              296.0
# p5                         5675.0             6972.0             4020.9
# p10                       12003.0          12573.958           11509.04
# p25                      20202.25           25763.11           24920.08
# p50                       31496.5           45725.05            46183.0
# p75                       56421.0           85296.53            86020.0
# p90                      103500.0          151821.74          158148.58
# p95                      157048.0        220638.7625        234766.7625
# p99                      385963.0          535233.77           534467.0
# max                      385963.0          535233.77           534467.0
#
#             credit_count_jun debit_count_jun max_credit_amount_jun  \
# dtype                  int64           int64               float64
# cardinality               39              65                  5718
# x_tot                  20000           20000                 20000
# x                      20000           20000                 20000
# nmiss                      0               0                     0
# perc_miss                0.0             0.0                   0.0
# sum                   398109          889961           956316532.8
# mean                19.90545        44.49805           47815.82664
# std                27.055323       35.006033          57339.279089
# var                731.99051     1225.422367     3287792926.408136
# lc_iqr                 -21.5           -79.5             -32762.25
# uc_iqr                  46.5           164.5             105175.75
# min                        1               0                 160.0
# p1                       1.0             0.0                 160.0
# p5                       2.0             2.0                1679.5
# p10                      2.0             7.0               11200.0
# p25                      4.0            12.0               18964.5
# p50                      7.0            37.0               30250.0
# p75                     21.0            73.0               53449.0
# p90                     58.0           103.0              100183.0
# p95                     94.0           106.0             150006.83
# p99                    117.0           124.0              377905.0
# max                      117             124              377905.0
#
#                    emi_active            cc_cons
# dtype                 float64            float64
# cardinality              5832              11990
# x_tot                   20000              20000
# x                       19999              15000
# nmiss                       1               5000
# perc_miss               0.005               25.0
# sum              201720730.94        826365410.0
# mean             10086.540874       55091.027333
# std              21303.303095       97429.489575
# var          453830722.744924  9492505438.819309
# lc_iqr             -10199.735         -13238.625
# uc_iqr              21122.065          40112.375
# min                    26.739             271.99
# p1                   26.73998           271.9999
# p5                     197.95            1290.85
# p10                    461.06             2633.6
# p25                   1545.94             6768.0
# p50                   3934.66            13364.0
# p75                   9376.39           20105.75
# p90                 19715.252           219688.7
# p95                  36148.07           309852.0
# p99              155033.14478        395290.0055
# max                155041.219          395290.55
#
# [23 rows x 37 columns]

# %%
# Seperating cc-cons from data, to carry out missing value imputation

# %%
cont_cust1 = cont_customer[['age', 'Emp_Tenure_Years', 'Tenure_with_Bank','Avg_days_between_transaction', 'cc_cons_apr',
       'dc_cons_apr', 'cc_cons_may', 'dc_cons_may', 'cc_cons_jun',
       'dc_cons_jun', 'cc_count_apr', 'cc_count_may', 'cc_count_jun',
       'dc_count_apr', 'dc_count_may', 'dc_count_jun','investment_1', 'investment_2', 'investment_3',
       'investment_4', 'debit_amount_apr', 'credit_amount_apr',
       'debit_count_apr', 'credit_count_apr', 'max_credit_amount_apr',
       'debit_amount_may', 'credit_amount_may', 'credit_count_may',
       'debit_count_may', 'max_credit_amount_may', 'debit_amount_jun',
       'credit_amount_jun', 'credit_count_jun', 'debit_count_jun',
       'max_credit_amount_jun','emi_active']]

# %%
cont_cust2 = cont_customer['cc_cons']

# %% [markdown]
# ##### Mising value Imputation

# %%
cont_col1 = ['age', 'Emp_Tenure_Years', 'Tenure_with_Bank','Avg_days_between_transaction', 'cc_cons_apr',
       'dc_cons_apr', 'cc_cons_may', 'dc_cons_may', 'cc_cons_jun',
       'dc_cons_jun', 'cc_count_apr', 'cc_count_may', 'cc_count_jun',
       'dc_count_apr', 'dc_count_may', 'dc_count_jun','investment_1', 'investment_2', 'investment_3',
       'investment_4', 'debit_amount_apr', 'credit_amount_apr',
       'debit_count_apr', 'credit_count_apr', 'max_credit_amount_apr',
       'debit_amount_may', 'credit_amount_may', 'credit_count_may',
       'debit_count_may', 'max_credit_amount_may', 'debit_amount_jun',
       'credit_amount_jun', 'credit_count_jun', 'debit_count_jun',
       'max_credit_amount_jun','emi_active']

# %%
for i in cont_col1:
    cont_cust1[i] = cont_cust1[i].fillna(cont_cust1[i].mean())
# Out:
# C:\Users\Tarun\AppData\Local\Temp\ipykernel_10116\78284495.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cont_cust1[i] = cont_cust1[i].fillna(cont_cust1[i].mean())

# %%
cont_cust1.isnull().sum()
# Out:
# age                             0
# Emp_Tenure_Years                0
# Tenure_with_Bank                0
# Avg_days_between_transaction    0
# cc_cons_apr                     0
# dc_cons_apr                     0
# cc_cons_may                     0
# dc_cons_may                     0
# cc_cons_jun                     0
# dc_cons_jun                     0
# cc_count_apr                    0
# cc_count_may                    0
# cc_count_jun                    0
# dc_count_apr                    0
# dc_count_may                    0
# dc_count_jun                    0
# investment_1                    0
# investment_2                    0
# investment_3                    0
# investment_4                    0
# debit_amount_apr                0
# credit_amount_apr               0
# debit_count_apr                 0
# credit_count_apr                0
# max_credit_amount_apr           0
# debit_amount_may                0
# credit_amount_may               0
# credit_count_may                0
# debit_count_may                 0
# max_credit_amount_may           0
# debit_amount_jun                0
# credit_amount_jun               0
# credit_count_jun                0
# debit_count_jun                 0
# max_credit_amount_jun           0
# emi_active                      0
# dtype: int64

# %%
cat_customer.isnull().sum()
# Out:
# account_type       1
# gender             1
# Income             1
# region_code        1
# NetBanking_Flag    0
# dtype: int64

# %%
for i in cat_col:
    cat_customer[i] = cat_customer[i].fillna(cat_customer[i].mode().iloc[0])

# %%
cat_customer.isnull().sum()
# Out:
# account_type       0
# gender             0
# Income             0
# region_code        0
# NetBanking_Flag    0
# dtype: int64

# %% [markdown]
# ##### Dummy Variables

# %%
cat_customer.Income.value_counts()
# Out:
# Income
# MEDIUM    12775
# LOW        5612
# HIGH       1613
# Name: count, dtype: int64

# %%
cat_customer['Income'] = pd.Series(np.where(cat_customer.Income=="LOW",1,np.where(cat_customer.Income=="Medium",2,3)))

# %%
cat_customer
# Out:
#       account_type gender  Income  region_code  NetBanking_Flag
# 0          current      M       3        628.0                1
# 1          current      M       3        656.0                0
# 2          current      F       3        314.0                1
# 3          current      M       3        614.0                1
# 4          current      M       3        750.0                1
# ...            ...    ...     ...          ...              ...
# 19995      current      F       3        354.0                1
# 19996      current      M       3        809.0                0
# 19997      current      F       3        466.0                0
# 19998      current      M       1        619.0                0
# 19999      current      F       1        882.0                1
#
# [20000 rows x 5 columns]

# %%
cat_customer.account_type.value_counts()
# Out:
# account_type
# current    16926
# saving      3074
# Name: count, dtype: int64

# %%
cat_customer.gender.value_counts()
# Out:
# gender
# M    17288
# F     2712
# Name: count, dtype: int64

# %%
for i in ['account_type', 'gender']:
    cols = pd.get_dummies(cat_customer[i], prefix=i, drop_first=True).astype(int)  # Convert to 0/1
    cat_customer = pd.concat([cat_customer, cols], axis=1)
    cat_customer.drop(i, axis=1, inplace=True)

# %%
cat_customer
# Out:
#        Income  region_code  NetBanking_Flag  account_type_saving  gender_M
# 0           3        628.0                1                    0         1
# 1           3        656.0                0                    0         1
# 2           3        314.0                1                    0         0
# 3           3        614.0                1                    0         1
# 4           3        750.0                1                    0         1
# ...       ...          ...              ...                  ...       ...
# 19995       3        354.0                1                    0         0
# 19996       3        809.0                0                    0         1
# 19997       3        466.0                0                    0         0
# 19998       1        619.0                0                    0         1
# 19999       1        882.0                1                    0         0
#
# [20000 rows x 5 columns]

# %%
cat_customer.region_code.value_counts()
# Out:
# region_code
# 249.0    509
# 683.0    380
# 867.0    369
# 748.0    356
# 355.0    354
#         ...
# 608.0      1
# 436.0      1
# 484.0      1
# 398.0      1
# 857.0      1
# Name: count, Length: 210, dtype: int64

# %%
cat_customer.NetBanking_Flag.value_counts()
# Out:
# NetBanking_Flag
# 1    14360
# 0     5640
# Name: count, dtype: int64

# %%
for i in ['region_code', 'NetBanking_Flag']:
    cat_customer[i] = cat_customer[i].astype('category')  # Convert to category
    cols = pd.get_dummies(cat_customer[i], prefix=i, drop_first=True).astype(int)  # Convert to 0/1
    cat_customer = pd.concat([cat_customer, cols], axis=1)
    cat_customer.drop(i, axis=1, inplace=True)

# %%
cat_customer
# Out:
#        Income  account_type_saving  gender_M  region_code_233.0  \
# 0           3                    0         1                  0
# 1           3                    0         1                  0
# 2           3                    0         0                  0
# 3           3                    0         1                  0
# 4           3                    0         1                  0
# ...       ...                  ...       ...                ...
# 19995       3                    0         0                  0
# 19996       3                    0         1                  0
# 19997       3                    0         0                  0
# 19998       1                    0         1                  0
# 19999       1                    0         0                  0
#
#        region_code_243.0  region_code_244.0  region_code_245.0  \
# 0                      0                  0                  0
# 1                      0                  0                  0
# 2                      0                  0                  0
# 3                      0                  0                  0
# 4                      0                  0                  0
# ...                  ...                ...                ...
# 19995                  0                  0                  0
# 19996                  0                  0                  0
# 19997                  0                  0                  0
# 19998                  0                  0                  0
# 19999                  0                  0                  0
#
#        region_code_247.0  region_code_248.0  region_code_249.0  ...  \
# 0                      0                  0                  0  ...
# 1                      0                  0                  0  ...
# 2                      0                  0                  0  ...
# 3                      0                  0                  0  ...
# 4                      0                  0                  0  ...
# ...                  ...                ...                ...  ...
# 19995                  0                  0                  0  ...
# 19996                  0                  0                  0  ...
# 19997                  0                  0                  0  ...
# 19998                  0                  0                  0  ...
# 19999                  0                  0                  0  ...
#
#        region_code_958.0  region_code_963.0  region_code_964.0  \
# 0                      0                  0                  0
# 1                      0                  0                  0
# 2                      0                  0                  0
# 3                      0                  0                  0
# 4                      0                  0                  0
# ...                  ...                ...                ...
# 19995                  0                  0                  0
# 19996                  0                  0                  0
# 19997                  0                  0                  0
# 19998                  0                  0                  0
# 19999                  0                  0                  0
#
#        region_code_965.0  region_code_966.0  region_code_968.0  \
# 0                      0                  0                  0
# 1                      0                  0                  0
# 2                      0                  0                  0
# 3                      0                  0                  0
# 4                      0                  0                  0
# ...                  ...                ...                ...
# 19995                  0                  0                  0
# 19996                  0                  0                  0
# 19997                  0                  0                  0
# 19998                  0                  0                  0
# 19999                  0                  0                  0
#
#        region_code_969.0  region_code_970.0  region_code_974.0  \
# 0                      0                  0                  0
# 1                      0                  0                  0
# 2                      0                  0                  0
# 3                      0                  0                  0
# 4                      0                  0                  0
# ...                  ...                ...                ...
# 19995                  0                  0                  0
# 19996                  0                  0                  0
# 19997                  0                  0                  0
# 19998                  0                  0                  0
# 19999                  0                  0                  0
#
#        NetBanking_Flag_1
# 0                      1
# 1                      0
# 2                      1
# 3                      1
# 4                      1
# ...                  ...
# 19995                  1
# 19996                  0
# 19997                  0
# 19998                  0
# 19999                  1
#
# [20000 rows x 213 columns]

# %%
cat_customer.columns = cat_customer.columns.str.replace('.','_')

# %%
cat_customer
# Out:
#        Income  account_type_saving  gender_M  region_code_233_0  \
# 0           3                    0         1                  0
# 1           3                    0         1                  0
# 2           3                    0         0                  0
# 3           3                    0         1                  0
# 4           3                    0         1                  0
# ...       ...                  ...       ...                ...
# 19995       3                    0         0                  0
# 19996       3                    0         1                  0
# 19997       3                    0         0                  0
# 19998       1                    0         1                  0
# 19999       1                    0         0                  0
#
#        region_code_243_0  region_code_244_0  region_code_245_0  \
# 0                      0                  0                  0
# 1                      0                  0                  0
# 2                      0                  0                  0
# 3                      0                  0                  0
# 4                      0                  0                  0
# ...                  ...                ...                ...
# 19995                  0                  0                  0
# 19996                  0                  0                  0
# 19997                  0                  0                  0
# 19998                  0                  0                  0
# 19999                  0                  0                  0
#
#        region_code_247_0  region_code_248_0  region_code_249_0  ...  \
# 0                      0                  0                  0  ...
# 1                      0                  0                  0  ...
# 2                      0                  0                  0  ...
# 3                      0                  0                  0  ...
# 4                      0                  0                  0  ...
# ...                  ...                ...                ...  ...
# 19995                  0                  0                  0  ...
# 19996                  0                  0                  0  ...
# 19997                  0                  0                  0  ...
# 19998                  0                  0                  0  ...
# 19999                  0                  0                  0  ...
#
#        region_code_958_0  region_code_963_0  region_code_964_0  \
# 0                      0                  0                  0
# 1                      0                  0                  0
# 2                      0                  0                  0
# 3                      0                  0                  0
# 4                      0                  0                  0
# ...                  ...                ...                ...
# 19995                  0                  0                  0
# 19996                  0                  0                  0
# 19997                  0                  0                  0
# 19998                  0                  0                  0
# 19999                  0                  0                  0
#
#        region_code_965_0  region_code_966_0  region_code_968_0  \
# 0                      0                  0                  0
# 1                      0                  0                  0
# 2                      0                  0                  0
# 3                      0                  0                  0
# 4                      0                  0                  0
# ...                  ...                ...                ...
# 19995                  0                  0                  0
# 19996                  0                  0                  0
# 19997                  0                  0                  0
# 19998                  0                  0                  0
# 19999                  0                  0                  0
#
#        region_code_969_0  region_code_970_0  region_code_974_0  \
# 0                      0                  0                  0
# 1                      0                  0                  0
# 2                      0                  0                  0
# 3                      0                  0                  0
# 4                      0                  0                  0
# ...                  ...                ...                ...
# 19995                  0                  0                  0
# 19996                  0                  0                  0
# 19997                  0                  0                  0
# 19998                  0                  0                  0
# 19999                  0                  0                  0
#
#        NetBanking_Flag_1
# 0                      1
# 1                      0
# 2                      1
# 3                      1
# 4                      1
# ...                  ...
# 19995                  1
# 19996                  0
# 19997                  0
# 19998                  0
# 19999                  1
#
# [20000 rows x 213 columns]

# %% [markdown]
# ##### Combining The data

# %%
clean_customer = pd.concat([cat_customer,cont_cust1],axis=1)

# %%
clean_customer = pd.concat([clean_customer, cont_cust2],axis=1)

# %%
# Seperating the data which is available and which we have to predict

# %%
clean_customer_avail = clean_customer[~clean_customer.cc_cons.isna()]

# %%
clean_customer_topred = clean_customer[clean_customer.cc_cons.isna()]

# %%
feature_columns = clean_customer_avail.columns.difference(['cc_cons'])

# %%
train_X, test_X, train_Y, test_Y = train_test_split(clean_customer_avail[feature_columns],clean_customer_avail['cc_cons'],test_size=0.3, random_state = 2)

# %%
# importing

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold

# %%
params = {'criterion':["squared_error","friedman_mse","absolute_error"],
    'max_depth':[5,6,7],
    'min_samples_split':[2,3,4],
    'min_samples_leaf': [3,4,5],
    'max_features':[None,"sqrt","log2"]}

# %%
DTR = GridSearchCV(DecisionTreeRegressor(),param_grid=params,cv=5,scoring='neg_root_mean_squared_error',n_jobs=-1)

# %%
DTR.fit(train_X,train_Y)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error'],
#                          'max_depth': [5, 6, 7],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'min_samples_leaf': [3, 4, 5],
#                          'min_samples_split': [2, 3, 4]},
#              scoring='neg_root_mean_squared_error')

# %%
DTR.best_score_
# Out:
# -98059.76455496301

# %%
DTR.best_params_
# Out:
# {'criterion': 'squared_error',
#  'max_depth': 5,
#  'max_features': 'log2',
#  'min_samples_leaf': 5,
#  'min_samples_split': 3}

# %%
DTRF=DecisionTreeRegressor(criterion='squared_error',max_depth=5,max_features='sqrt',min_samples_leaf=5,min_samples_split=3)

# %%
DTRF.fit(train_X,train_Y)
# Out:
# DecisionTreeRegressor(max_depth=5, max_features='sqrt', min_samples_leaf=5,
#                       min_samples_split=3)

# %% [markdown]
# ###### Model Validation using RMSPE

# %%
trainpredval = pd.Series(DTRF.predict(train_X))

# %%
np.sqrt(np.mean(np.square(((train_Y-trainpredval)/train_Y)*100)))
# Out:
# 2911.643423645129

# %%
testpredval = pd.Series(DTRF.predict(test_X))

# %%
np.sqrt(np.mean(np.square(((train_Y-testpredval)/train_Y)*100)))
# Out:
# 2756.735049977024

# %% [markdown]
# ##### Missing Values Predicted Output

# %%
clean_customer_topred.drop(columns='cc_cons',inplace=True)
# Out:
# C:\Users\Tarun\AppData\Local\Temp\ipykernel_10116\364805491.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_customer_topred.drop(columns='cc_cons',inplace=True)

# %%
clean_customer_topred.columns
# Out:
# Index(['Avg_days_between_transaction', 'Emp_Tenure_Years', 'Income',
#        'NetBanking_Flag_1', 'Tenure_with_Bank', 'account_type_saving', 'age',
#        'cc_cons_apr', 'cc_cons_jun', 'cc_cons_may',
#        ...
#        'region_code_957_0', 'region_code_958_0', 'region_code_963_0',
#        'region_code_964_0', 'region_code_965_0', 'region_code_966_0',
#        'region_code_968_0', 'region_code_969_0', 'region_code_970_0',
#        'region_code_974_0'],
#       dtype='object', length=249)

# %%
clean_customer_topred = clean_customer_topred.reindex(sorted(clean_customer_topred.columns),axis=1)

# %%
prediction_value = pd.Series(DTRF.predict(clean_customer_topred))

# %%
prediction_value
# Out:
# 0       63748.177287
# 1       63748.177287
# 2       48014.278628
# 3       48014.278628
# 4       63748.177287
#             ...
# 4995    48014.278628
# 4996    54896.734089
# 4997    54896.734089
# 4998    54896.734089
# 4999    54896.734089
# Length: 5000, dtype: float64
